# %%
from stemsegmentation import segmentationSTEM

# %%
import numpy as np 
import matplotlib.pyplot as plt
import time

# %%
image = np.load('high_entropy_alloy.npy')

# %%
plt.imshow(image)

# %%
plt.imshow(image)

# %%
step = 5

# %%
descriptor_name = 'local_correlation_map'
seg = segmentationSTEM( n_patterns=2,
                       window_x=20,window_y=20,
                       patch_x=20,patch_y=20,
                       step=step,
                       descriptor_name=descriptor_name,
                       upsampling=True)
start = time.time()
labels = seg.perform_clustering(image)
print ('time_cost: %6.2f[s]' %(time.time()-start,))
# Out:
# time_cost:   4.96[s]

# %%
plt.imshow(labels)

# %%
logarithm = False

# %%
descriptor_name = 'power_spectrum'
seg = segmentationSTEM( n_patterns=2,
                       window_x=20,window_y=20,
                       step=step,
                       descriptor_name=descriptor_name,
                       upsampling=True,
                      power_spectrum_logarithm=logarithm)
start = time.time()
labels = seg.perform_clustering(image)
print ('time_cost: %6.2f[s]' %(time.time()-start,))
# Out:
# time_cost:   6.56[s]

# %%
plt.imshow(labels)

# %%
logarithm = True

# %%
descriptor_name = 'power_spectrum'
seg = segmentationSTEM( n_patterns=2,
                       window_x=20,window_y=20,
                       step=step,
                       descriptor_name=descriptor_name,
                       upsampling=True,
                      power_spectrum_logarithm=logarithm)
start = time.time()
labels = seg.perform_clustering(image)
print ('time_cost: %6.2f[s]' %(time.time()-start,))
# Out:
# time_cost:   8.15[s]

# %%
plt.imshow(labels)

# %%
logarithm = False

# %%
descriptor_name = 'power_spectrum'
seg = segmentationSTEM( n_patterns=3,
                       window_x=20,window_y=20,
                       step=step,
                       descriptor_name=descriptor_name,
                       upsampling=True,
                      power_spectrum_logarithm=logarithm)
start = time.time()
labels = seg.perform_clustering(image)
print ('time_cost: %6.2f[s]' %(time.time()-start,))
# Out:
# time_cost:   6.50[s]

# %%
plt.imshow(labels)

# %%
logarithm = True

# %%
descriptor_name = 'power_spectrum'
seg = segmentationSTEM( n_patterns=3,
                       window_x=20,window_y=20,
                       step=step,
                       descriptor_name=descriptor_name,
                       upsampling=True,
                      power_spectrum_logarithm=logarithm)
start = time.time()
labels = seg.perform_clustering(image)
print ('time_cost: %6.2f[s]' %(time.time()-start,))
# Out:
# time_cost:   8.69[s]

# %%
plt.imshow(labels)

# %%
descriptor_name = 'reflection_symmetry_maximums'
seg = segmentationSTEM( n_patterns=2,
                       window_x=20,window_y=20,
                       radius=20,
                       descriptor_name=descriptor_name,
                       upsampling=True)
start = time.time()
labels = seg.perform_clustering(image)
print ('time_cost: %6.2f[s]' %(time.time()-start,))
# Out:
# time_cost:  88.50[s]

# %%
plt.imshow(labels)

# %%
descriptor_name = 'rotational_symmetry_maximums'
seg = segmentationSTEM( n_patterns=2,
                       window_x=20,window_y=20,
                       radius=20,
                       descriptor_name=descriptor_name,
                       upsampling=True)
start = time.time()
labels = seg.perform_clustering(image)
print ('time_cost: %6.2f[s]' %(time.time()-start,))
# Out:
# time_cost:  81.80[s]

# %%
plt.imshow(labels)
