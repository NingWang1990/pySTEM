# %%
import numpy as np

# %%
from pystem import segmentationSTEM

# %%
import matplotlib.pyplot as plt

# %%
video = np.load('video_for_paper.npy')

# %%
plt.imshow(video[0])

# %%
seg = segmentationSTEM(n_patterns=2,
                       window_x=16,window_y=16,
                       patch_x=16,patch_y=16,
                       step=10,
                       descriptor_name='local_correlation_map',
                      upsampling=True)

# %%
labels = seg.perform_clustering(video[0])
# Out:
# method: direct

# %%
video[0].shape
# Out:
# (400, 300)

# %%
labels.shape
# Out:
# (400, 300)

# %%
descriptors = seg._descriptors

# %%
plt.imshow(labels)

# %%
descriptors.shape
# Out:
# (336, 236, 81)
